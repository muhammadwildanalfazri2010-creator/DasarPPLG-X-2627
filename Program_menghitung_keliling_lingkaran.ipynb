# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadwildanalfazri2010-creator/DasarPPLG-X-2627/blob/main/Program_menghitung_keliling_lingkaran.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !g++ --version
# Out:
# g++ (Ubuntu 13.3.0-6ubuntu2~24.04.1) 13.3.0
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %%writefile keliling_lingkaran.cpp
# #include <iostream>
# using namespace std;
#
# int main()
# {
#     float r, keliling;
#
#     cout << "Program aplikasi menghitung keliling lingkaran" << endl;
#     cout << "Masukkan jari jari lingkaran" << endl;
#     cin >> r;
#
#     keliling = 2 * 3.14 * r;
#
#     cout << "Keliling lingkaran = " << keliling << endl;
#
#     return 0;
# }
# Out:
# Writing keliling_lingkaran.cpp

# %%
# !g++ keliling_lingkaran.cpp -o main

# %%
! ./main
# Out:
# Program aplikasi menghitung keliling lingkaran
# Masukkan jari jari lingkaran
# 8
# Keliling lingkaran = 50.24
